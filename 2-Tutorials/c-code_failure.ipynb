# %% [markdown]
# # Finite Element Error Tutorial
# #### Extreme Axial Compression
#
# This example shows how mesh choice and geometrical instability can give unpredictable results in large-deformation scenarios.

# %%
import os
import warnings
warnings.simplefilter("always")
from finiteelementanalysis import pre_process as pre
from finiteelementanalysis import pre_process_demo_helper_fcns as pre_demo
from finiteelementanalysis.solver import hyperelastic_solver
from finiteelementanalysis import visualize as viz
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %% [markdown]
# ## Create Geometry and Mesh
#
# In this example, we consider a simple 2 dimensional rectangular beam, meshed rather coarsely along its length.

# %%
# for saving files later
tutorials_dir = os.path.abspath('')

# FEA problem info
ele_type = "D2_nn6_tri"
ndof = 2

# Define domain
L = 10.0      # twice length in x-direction
H = 0.2      # height in y-direction
nx = 10       # number of elements in x
ny = 4       # number of elements in y, keep this an even number if you want the analytical solution to be able to compute midline deformation

# Generate mesh
coords, connect = pre.generate_rect_mesh_2d(ele_type, -L/2, -H/2, 0, H/2, nx, ny)

mesh_img_fname = tutorials_dir + "/c-mesh.png"
pre_demo.plot_mesh_2D(str(mesh_img_fname), ele_type, coords, connect)

# %% [markdown]
# ![mesh image](c-mesh.png "Mesh")

# %% [markdown]
# ## Specify a Material and Apply Boundary Conditions
#
# After assigning suitable material properties, we apply boundary conditions to compress the beam axially.
# We specify that the ends should move towards each other with a speed of 0.7, and should be fixed in the y-direction.

# %%
# Choose material properties
material_props = np.array([134.6, 83.33])  # [mu, K]

# Identify boundaries
boundary_nodes, boundary_edges = pre.identify_rect_boundaries(coords, connect, ele_type, -L/2, 0, -H/2, H/2)

# Apply boundary conditions:
# 1. Fix left end boundary
fixed_left = pre.assign_fixed_nodes_rect(boundary_nodes, "left", 0.7, 0)
# 2. Fix right end boundary
fixed_right = pre.assign_fixed_nodes_rect(boundary_nodes, "right", -0.7, 0)
# Combine BCs (assuming the functions return arrays of shape (3, n_bc))
fixed_nodes = np.hstack((fixed_left, fixed_right))

# No distributed load is applied
dload_info = np.empty((ndof + 2, 0))

# %% [markdown]
# ## Run the Solver

# %%
# Number of incremental loading steps
nr_num_steps = 100

# Run the solver
displacements_all, nr_info_all = hyperelastic_solver(
    material_props,
    ele_type,
    coords.T,      # solver expects coords as (ncoord, n_nodes)
    connect.T,     # and connectivity as (n_nodes_per_elem, n_elems)
    fixed_nodes,
    dload_info,
    nr_print=True,
    nr_num_steps=nr_num_steps,
    nr_tol=1e-8,
    nr_maxit=30,
)

final_disp = displacements_all[-1]  # final global displacement vector (length = n_nodes * ndof)

# Analytical solution: For a homogeneous extension,
#   u_x(x) = (lambda_target - 1) * x, and u_y(x) = 0.
# Extract nodes near mid-height to get a 1D slice.
tol_y = H / 20.0  # tolerance for y coordinate
mid_nodes = [i for i in range(coords.shape[0]) if abs(coords[i, 1] - H/2) < tol_y]
mid_nodes = sorted(mid_nodes, key=lambda i: coords[i, 0])  # sort by x-coordinate

# Extract y-coordinates and computed u_y from the final displacement.
x_vals = np.array([coords[i, 0] for i in mid_nodes])
computed_u_y = np.array([final_disp[ndof * i + 1] for i in mid_nodes])
# Out:
# Step 0, load factor = 0.010
# Iteration 1, Correction=1.000000e+00, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=5.228553e-05, Residual=3.524575e-06, tolerance=1.000000e-08
# Iteration 3, Correction=8.322217e-09, Residual=8.842394e-12, tolerance=1.000000e-08
# Step 1, load factor = 0.020
# Iteration 1, Correction=5.000005e-01, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.953569e-05, Residual=3.543158e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.697454e-08, Residual=8.924466e-12, tolerance=1.000000e-08
# Iteration 4, Correction=1.255522e-13, Residual=1.820751e-16, tolerance=1.000000e-08
# Step 2, load factor = 0.030
# Iteration 1, Correction=3.333342e-01, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=9.852214e-05, Residual=3.561669e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.125453e-07, Residual=8.213655e-12, tolerance=1.000000e-08
# Iteration 4, Correction=1.304124e-14, Residual=1.958979e-16, tolerance=1.000000e-08
# Step 3, load factor = 0.040
# Iteration 1, Correction=2.500013e-01, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.824350e-03, Residual=3.580156e-06, tolerance=1.000000e-08
# Iteration 3, Correction=5.484087e-05, Residual=6.450044e-09, tolerance=1.000000e-08
# Iteration 4, Correction=2.713167e-09, Residual=1.325391e-12, tolerance=1.000000e-08
# Step 4, load factor = 0.050
# Iteration 1, Correction=2.027502e-01, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.152139e-02, Residual=4.566822e-06, tolerance=1.000000e-08
# Iteration 3, Correction=5.521047e-05, Residual=6.834905e-07, tolerance=1.000000e-08
# Iteration 4, Correction=1.982144e-08, Residual=2.247443e-12, tolerance=1.000000e-08
# Iteration 5, Correction=8.215472e-15, Residual=1.795980e-16, tolerance=1.000000e-08
# Step 5, load factor = 0.060
# Iteration 1, Correction=1.666683e-01, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=6.638771e-05, Residual=3.616738e-06, tolerance=1.000000e-08
# Iteration 3, Correction=3.619001e-08, Residual=8.319691e-12, tolerance=1.000000e-08
# Iteration 4, Correction=5.019754e-15, Residual=2.179690e-16, tolerance=1.000000e-08
# Step 6, load factor = 0.070
# Iteration 1, Correction=1.428589e-01, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.176507e-05, Residual=3.634881e-06, tolerance=1.000000e-08
# Iteration 3, Correction=4.378858e-09, Residual=9.464677e-12, tolerance=1.000000e-08
# Step 7, load factor = 0.080
# Iteration 1, Correction=1.250019e-01, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.016278e-05, Residual=3.652965e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.630144e-09, Residual=9.543878e-12, tolerance=1.000000e-08
# Step 8, load factor = 0.090
# Iteration 1, Correction=1.111131e-01, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.565212e-05, Residual=3.670966e-06, tolerance=1.000000e-08
# Iteration 3, Correction=4.916747e-09, Residual=9.254548e-12, tolerance=1.000000e-08
# Step 9, load factor = 0.100
# Iteration 1, Correction=1.000022e-01, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.156289e-05, Residual=3.688903e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.424169e-08, Residual=8.972993e-12, tolerance=1.000000e-08
# Iteration 4, Correction=3.354675e-15, Residual=3.258262e-16, tolerance=1.000000e-08
# Step 10, load factor = 0.110
# Iteration 1, Correction=9.091147e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=9.419717e-05, Residual=3.706902e-06, tolerance=1.000000e-08
# Iteration 3, Correction=7.253111e-08, Residual=7.791985e-11, tolerance=1.000000e-08
# Iteration 4, Correction=5.741994e-15, Residual=2.943341e-16, tolerance=1.000000e-08
# Step 11, load factor = 0.120
# Iteration 1, Correction=8.333648e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=7.716110e-04, Residual=3.726446e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.891243e-06, Residual=6.653463e-09, tolerance=1.000000e-08
# Iteration 4, Correction=1.290350e-11, Residual=4.009870e-14, tolerance=1.000000e-08
# Step 12, load factor = 0.130
# Iteration 1, Correction=7.699587e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=6.145648e-03, Residual=3.941462e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.506623e-05, Residual=4.963185e-07, tolerance=1.000000e-08
# Iteration 4, Correction=6.569962e-09, Residual=3.021796e-12, tolerance=1.000000e-08
# Step 13, load factor = 0.140
# Iteration 1, Correction=7.146654e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.460976e-03, Residual=3.867449e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.115650e-06, Residual=3.253267e-08, tolerance=1.000000e-08
# Iteration 4, Correction=1.118234e-11, Residual=1.913270e-14, tolerance=1.000000e-08
# Step 14, load factor = 0.150
# Iteration 1, Correction=6.666990e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.007492e-04, Residual=3.778395e-06, tolerance=1.000000e-08
# Iteration 3, Correction=4.553862e-08, Residual=1.751240e-10, tolerance=1.000000e-08
# Iteration 4, Correction=3.226422e-15, Residual=5.236750e-16, tolerance=1.000000e-08
# Step 15, load factor = 0.160
# Iteration 1, Correction=6.250290e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=2.453981e-05, Residual=3.794098e-06, tolerance=1.000000e-08
# Iteration 3, Correction=8.150025e-09, Residual=1.195460e-11, tolerance=1.000000e-08
# Step 16, load factor = 0.170
# Iteration 1, Correction=5.882649e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=9.278914e-06, Residual=3.810997e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.481663e-09, Residual=9.987993e-12, tolerance=1.000000e-08
# Step 17, load factor = 0.180
# Iteration 1, Correction=5.555861e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=5.036069e-06, Residual=3.827914e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.080318e-09, Residual=1.064377e-11, tolerance=1.000000e-08
# Step 18, load factor = 0.190
# Iteration 1, Correction=5.263473e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.276297e-06, Residual=3.844738e-06, tolerance=1.000000e-08
# Iteration 3, Correction=7.229194e-10, Residual=1.081028e-11, tolerance=1.000000e-08
# Step 19, load factor = 0.200
# Iteration 1, Correction=5.000326e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.939699e-06, Residual=3.861452e-06, tolerance=1.000000e-08
# Iteration 3, Correction=7.861928e-10, Residual=1.074226e-11, tolerance=1.000000e-08
# Step 20, load factor = 0.210
# Iteration 1, Correction=4.762241e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=6.541497e-06, Residual=3.878062e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.144901e-09, Residual=1.041256e-11, tolerance=1.000000e-08
# Step 21, load factor = 0.220
# Iteration 1, Correction=4.545801e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=9.473380e-06, Residual=3.894599e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.944011e-09, Residual=1.012547e-11, tolerance=1.000000e-08
# Step 22, load factor = 0.230
# Iteration 1, Correction=4.348185e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.506382e-05, Residual=3.911152e-06, tolerance=1.000000e-08
# Iteration 3, Correction=3.767716e-09, Residual=1.586849e-11, tolerance=1.000000e-08
# Step 23, load factor = 0.240
# Iteration 1, Correction=4.167040e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=2.701673e-05, Residual=3.927994e-06, tolerance=1.000000e-08
# Iteration 3, Correction=8.620350e-09, Residual=5.817353e-11, tolerance=1.000000e-08
# Step 24, load factor = 0.250
# Iteration 1, Correction=4.000400e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=5.792909e-05, Residual=3.946161e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.532849e-08, Residual=3.091107e-10, tolerance=1.000000e-08
# Iteration 4, Correction=6.545612e-16, Residual=7.054286e-16, tolerance=1.000000e-08
# Step 25, load factor = 0.260
# Iteration 1, Correction=3.846634e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.701052e-04, Residual=3.971148e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.155817e-07, Residual=2.927466e-09, tolerance=1.000000e-08
# Iteration 4, Correction=8.612147e-14, Residual=1.568582e-15, tolerance=1.000000e-08
# Step 26, load factor = 0.270
# Iteration 1, Correction=3.704740e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.082753e-03, Residual=4.058108e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.154708e-06, Residual=1.280925e-07, tolerance=1.000000e-08
# Iteration 4, Correction=9.663676e-11, Residual=1.505312e-13, tolerance=1.000000e-08
# Step 27, load factor = 0.280
# Iteration 1, Correction=3.598566e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.253460e-02, Residual=7.090437e-06, tolerance=1.000000e-08
# Iteration 3, Correction=3.267132e-04, Residual=1.846844e-05, tolerance=1.000000e-08
# Iteration 4, Correction=7.106667e-06, Residual=1.277136e-08, tolerance=1.000000e-08
# Iteration 5, Correction=9.461663e-11, Residual=5.926209e-12, tolerance=1.000000e-08
# Step 28, load factor = 0.290
# Iteration 1, Correction=3.699548e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=9.987847e-03, Residual=2.905190e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.364857e-04, Residual=1.256971e-05, tolerance=1.000000e-08
# Iteration 4, Correction=5.315497e-07, Residual=2.406537e-09, tolerance=1.000000e-08
# Iteration 5, Correction=4.324020e-13, Residual=3.547795e-14, tolerance=1.000000e-08
# Step 29, load factor = 0.300
# Iteration 1, Correction=3.334981e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.863697e-04, Residual=4.196617e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.207851e-07, Residual=2.013636e-08, tolerance=1.000000e-08
# Iteration 4, Correction=7.932287e-13, Residual=6.794312e-15, tolerance=1.000000e-08
# Step 30, load factor = 0.310
# Iteration 1, Correction=3.226362e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=8.710073e-05, Residual=4.054471e-06, tolerance=1.000000e-08
# Iteration 3, Correction=3.165021e-08, Residual=1.087285e-09, tolerance=1.000000e-08
# Iteration 4, Correction=4.014611e-15, Residual=8.452831e-16, tolerance=1.000000e-08
# Step 31, load factor = 0.320
# Iteration 1, Correction=3.125466e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.197866e-05, Residual=4.054048e-06, tolerance=1.000000e-08
# Iteration 3, Correction=8.857050e-09, Residual=1.509373e-10, tolerance=1.000000e-08
# Step 32, load factor = 0.330
# Iteration 1, Correction=3.030758e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.492279e-05, Residual=4.065308e-06, tolerance=1.000000e-08
# Iteration 3, Correction=3.373017e-09, Residual=3.149613e-11, tolerance=1.000000e-08
# Step 33, load factor = 0.340
# Iteration 1, Correction=2.941634e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=8.076528e-06, Residual=4.078573e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.548644e-09, Residual=1.179666e-11, tolerance=1.000000e-08
# Step 34, load factor = 0.350
# Iteration 1, Correction=2.857607e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.890903e-06, Residual=4.092245e-06, tolerance=1.000000e-08
# Iteration 3, Correction=8.111527e-10, Residual=1.146799e-11, tolerance=1.000000e-08
# Step 35, load factor = 0.360
# Iteration 1, Correction=2.778249e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.300788e-06, Residual=4.105928e-06, tolerance=1.000000e-08
# Iteration 3, Correction=4.734389e-10, Residual=1.238695e-11, tolerance=1.000000e-08
# Step 36, load factor = 0.370
# Iteration 1, Correction=2.703182e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=2.520869e-06, Residual=4.119494e-06, tolerance=1.000000e-08
# Iteration 3, Correction=3.087074e-10, Residual=1.289180e-11, tolerance=1.000000e-08
# Step 37, load factor = 0.380
# Iteration 1, Correction=2.632067e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=2.203144e-06, Residual=4.132895e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.319586e-10, Residual=1.313107e-11, tolerance=1.000000e-08
# Step 38, load factor = 0.390
# Iteration 1, Correction=2.564598e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=2.171903e-06, Residual=4.146114e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.091179e-10, Residual=1.320471e-11, tolerance=1.000000e-08
# Step 39, load factor = 0.400
# Iteration 1, Correction=2.500504e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=2.341757e-06, Residual=4.159146e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.255429e-10, Residual=1.313306e-11, tolerance=1.000000e-08
# Step 40, load factor = 0.410
# Iteration 1, Correction=2.439536e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=2.690873e-06, Residual=4.171999e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.766419e-10, Residual=1.289128e-11, tolerance=1.000000e-08
# Step 41, load factor = 0.420
# Iteration 1, Correction=2.381473e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.248663e-06, Residual=4.184696e-06, tolerance=1.000000e-08
# Iteration 3, Correction=3.681855e-10, Residual=1.246306e-11, tolerance=1.000000e-08
# Step 42, load factor = 0.430
# Iteration 1, Correction=2.326110e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.097300e-06, Residual=4.197285e-06, tolerance=1.000000e-08
# Iteration 3, Correction=5.198201e-10, Residual=1.212569e-11, tolerance=1.000000e-08
# Step 43, load factor = 0.440
# Iteration 1, Correction=2.273264e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=5.395535e-06, Residual=4.209862e-06, tolerance=1.000000e-08
# Iteration 3, Correction=7.743618e-10, Residual=1.390098e-11, tolerance=1.000000e-08
# Step 44, load factor = 0.450
# Iteration 1, Correction=2.222769e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=7.442855e-06, Residual=4.222622e-06, tolerance=1.000000e-08
# Iteration 3, Correction=1.222606e-09, Residual=2.475597e-11, tolerance=1.000000e-08
# Step 45, load factor = 0.460
# Iteration 1, Correction=2.174471e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.083506e-05, Residual=4.236000e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.070082e-09, Residual=5.924591e-11, tolerance=1.000000e-08
# Step 46, load factor = 0.470
# Iteration 1, Correction=2.128232e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.686658e-05, Residual=4.251030e-06, tolerance=1.000000e-08
# Iteration 3, Correction=3.834659e-09, Residual=1.604637e-10, tolerance=1.000000e-08
# Step 47, load factor = 0.480
# Iteration 1, Correction=2.083931e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=2.871465e-05, Residual=4.270526e-06, tolerance=1.000000e-08
# Iteration 3, Correction=8.028708e-09, Residual=5.023470e-10, tolerance=1.000000e-08
# Step 48, load factor = 0.490
# Iteration 1, Correction=2.041467e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=5.564410e-05, Residual=4.303562e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.007305e-08, Residual=1.994824e-09, tolerance=1.000000e-08
# Iteration 4, Correction=3.558200e-15, Residual=1.271125e-15, tolerance=1.000000e-08
# Step 49, load factor = 0.500
# Iteration 1, Correction=2.000810e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.328108e-04, Residual=4.387701e-06, tolerance=1.000000e-08
# Iteration 3, Correction=6.591808e-08, Residual=1.189810e-08, tolerance=1.000000e-08
# Iteration 4, Correction=1.220277e-13, Residual=3.165599e-15, tolerance=1.000000e-08
# Step 50, load factor = 0.510
# Iteration 1, Correction=1.962351e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.738118e-04, Residual=4.752167e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.945580e-07, Residual=1.579087e-07, tolerance=1.000000e-08
# Iteration 4, Correction=1.211308e-11, Residual=5.258932e-14, tolerance=1.000000e-08
# Step 51, load factor = 0.520
# Iteration 1, Correction=1.933096e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=6.105349e-03, Residual=8.134023e-06, tolerance=1.000000e-08
# Iteration 3, Correction=2.777280e-04, Residual=2.729391e-05, tolerance=1.000000e-08
# Iteration 4, Correction=8.967965e-06, Residual=5.608577e-08, tolerance=1.000000e-08
# Iteration 5, Correction=1.607200e-09, Residual=5.881987e-11, tolerance=1.000000e-08
# Step 52, load factor = 0.530
# Iteration 1, Correction=3.450434e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=9.402559e-02, Residual=6.375374e-04, tolerance=1.000000e-08
# Iteration 3, Correction=2.689967e-02, Residual=7.064574e-03, tolerance=1.000000e-08
# Iteration 4, Correction=2.296198e-02, Residual=6.405569e-04, tolerance=1.000000e-08
# Iteration 5, Correction=1.054323e-02, Residual=4.200653e-04, tolerance=1.000000e-08
# Iteration 6, Correction=3.128877e-03, Residual=8.858681e-05, tolerance=1.000000e-08
# Iteration 7, Correction=2.700126e-04, Residual=7.727440e-06, tolerance=1.000000e-08
# Iteration 8, Correction=1.999699e-06, Residual=5.746243e-08, tolerance=1.000000e-08
# Iteration 9, Correction=1.096212e-10, Residual=3.151373e-12, tolerance=1.000000e-08
# Step 53, load factor = 0.540
# Iteration 1, Correction=4.882901e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=6.968338e-03, Residual=1.647389e-03, tolerance=1.000000e-08
# Iteration 3, Correction=1.772660e-03, Residual=4.324800e-05, tolerance=1.000000e-08
# Iteration 4, Correction=5.183674e-05, Residual=2.670980e-06, tolerance=1.000000e-08
# Iteration 5, Correction=5.178448e-08, Residual=2.318100e-09, tolerance=1.000000e-08
# Iteration 6, Correction=4.973545e-14, Residual=2.844908e-15, tolerance=1.000000e-08
# Step 54, load factor = 0.550
# Iteration 1, Correction=3.518712e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.037273e-03, Residual=7.605772e-04, tolerance=1.000000e-08
# Iteration 3, Correction=2.492455e-04, Residual=8.927038e-06, tolerance=1.000000e-08
# Iteration 4, Correction=8.407301e-07, Residual=5.723814e-08, tolerance=1.000000e-08
# Iteration 5, Correction=1.110926e-11, Residual=6.655079e-13, tolerance=1.000000e-08
# Step 55, load factor = 0.560
# Iteration 1, Correction=2.985121e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.731888e-03, Residual=4.991465e-04, tolerance=1.000000e-08
# Iteration 3, Correction=6.820332e-05, Residual=3.156875e-06, tolerance=1.000000e-08
# Iteration 4, Correction=5.511593e-08, Residual=4.637688e-09, tolerance=1.000000e-08
# Iteration 5, Correction=4.157096e-14, Residual=3.775315e-15, tolerance=1.000000e-08
# Step 56, load factor = 0.570
# Iteration 1, Correction=2.684661e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.137565e-03, Residual=3.755385e-04, tolerance=1.000000e-08
# Iteration 3, Correction=2.610517e-05, Residual=1.476236e-06, tolerance=1.000000e-08
# Iteration 4, Correction=7.311658e-09, Residual=7.339053e-10, tolerance=1.000000e-08
# Step 57, load factor = 0.580
# Iteration 1, Correction=2.484578e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=8.132941e-04, Residual=3.037691e-04, tolerance=1.000000e-08
# Iteration 3, Correction=1.217448e-05, Residual=8.147155e-07, tolerance=1.000000e-08
# Iteration 4, Correction=1.470653e-09, Residual=1.721479e-10, tolerance=1.000000e-08
# Step 58, load factor = 0.590
# Iteration 1, Correction=2.337723e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=6.149818e-04, Residual=2.569901e-04, tolerance=1.000000e-08
# Iteration 3, Correction=6.463274e-06, Residual=5.011094e-07, tolerance=1.000000e-08
# Iteration 4, Correction=3.888797e-10, Residual=5.225251e-11, tolerance=1.000000e-08
# Step 59, load factor = 0.600
# Iteration 1, Correction=2.222889e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.838556e-04, Residual=2.241498e-04, tolerance=1.000000e-08
# Iteration 3, Correction=3.759694e-06, Residual=3.325427e-07, tolerance=1.000000e-08
# Iteration 4, Correction=1.247555e-10, Residual=1.901709e-11, tolerance=1.000000e-08
# Step 60, load factor = 0.610
# Iteration 1, Correction=2.129046e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.920992e-04, Residual=1.998734e-04, tolerance=1.000000e-08
# Iteration 3, Correction=2.340684e-06, Residual=2.333746e-07, tolerance=1.000000e-08
# Iteration 4, Correction=4.621057e-11, Residual=7.918463e-12, tolerance=1.000000e-08
# Step 61, load factor = 0.620
# Iteration 1, Correction=2.049851e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.250712e-04, Residual=1.812353e-04, tolerance=1.000000e-08
# Iteration 3, Correction=1.535699e-06, Residual=1.709319e-07, tolerance=1.000000e-08
# Iteration 4, Correction=1.912954e-11, Residual=3.657159e-12, tolerance=1.000000e-08
# Step 62, load factor = 0.630
# Iteration 1, Correction=1.981381e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=2.744261e-04, Residual=1.665077e-04, tolerance=1.000000e-08
# Iteration 3, Correction=1.050493e-06, Residual=1.294759e-07, tolerance=1.000000e-08
# Iteration 4, Correction=8.653008e-12, Residual=1.834053e-12, tolerance=1.000000e-08
# Step 63, load factor = 0.640
# Iteration 1, Correction=1.921065e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=2.351028e-04, Residual=1.546049e-04, tolerance=1.000000e-08
# Iteration 3, Correction=7.434628e-07, Residual=1.007602e-07, tolerance=1.000000e-08
# Iteration 4, Correction=4.208189e-12, Residual=9.830815e-13, tolerance=1.000000e-08
# Step 64, load factor = 0.650
# Iteration 1, Correction=1.867142e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=2.038761e-04, Residual=1.448108e-04, tolerance=1.000000e-08
# Iteration 3, Correction=5.412775e-07, Residual=8.016542e-08, tolerance=1.000000e-08
# Iteration 4, Correction=2.173785e-12, Residual=5.567640e-13, tolerance=1.000000e-08
# Step 65, load factor = 0.660
# Iteration 1, Correction=1.818359e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.786061e-04, Residual=1.366341e-04, tolerance=1.000000e-08
# Iteration 3, Correction=4.036293e-07, Residual=6.495925e-08, tolerance=1.000000e-08
# Iteration 4, Correction=1.182321e-12, Residual=3.304813e-13, tolerance=1.000000e-08
# Step 66, load factor = 0.670
# Iteration 1, Correction=1.773798e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.578244e-04, Residual=1.297268e-04, tolerance=1.000000e-08
# Iteration 3, Correction=3.072367e-07, Residual=5.345093e-08, tolerance=1.000000e-08
# Iteration 4, Correction=6.721528e-13, Residual=2.037037e-13, tolerance=1.000000e-08
# Step 67, load factor = 0.680
# Iteration 1, Correction=1.732766e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.404946e-04, Residual=1.238353e-04, tolerance=1.000000e-08
# Iteration 3, Correction=2.380787e-07, Residual=4.455370e-08, tolerance=1.000000e-08
# Iteration 4, Correction=3.973409e-13, Residual=1.303223e-13, tolerance=1.000000e-08
# Step 68, load factor = 0.690
# Iteration 1, Correction=1.694731e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.258672e-04, Residual=1.187710e-04, tolerance=1.000000e-08
# Iteration 3, Correction=1.874038e-07, Residual=3.754604e-08, tolerance=1.000000e-08
# Iteration 4, Correction=2.430670e-13, Residual=8.578294e-14, tolerance=1.000000e-08
# Step 69, load factor = 0.700
# Iteration 1, Correction=1.659273e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.133895e-04, Residual=1.143902e-04, tolerance=1.000000e-08
# Iteration 3, Correction=1.495783e-07, Residual=3.193540e-08, tolerance=1.000000e-08
# Iteration 4, Correction=1.536771e-13, Residual=5.758879e-14, tolerance=1.000000e-08
# Step 70, load factor = 0.710
# Iteration 1, Correction=1.626057e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=1.026463e-04, Residual=1.105822e-04, tolerance=1.000000e-08
# Iteration 3, Correction=1.208767e-07, Residual=2.737742e-08, tolerance=1.000000e-08
# Iteration 4, Correction=9.977445e-14, Residual=3.995792e-14, tolerance=1.000000e-08
# Step 71, load factor = 0.720
# Iteration 1, Correction=1.594813e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=9.332171e-05, Residual=1.072600e-04, tolerance=1.000000e-08
# Iteration 3, Correction=9.877595e-08, Residual=2.362629e-08, tolerance=1.000000e-08
# Iteration 4, Correction=6.656847e-14, Residual=2.812248e-14, tolerance=1.000000e-08
# Step 72, load factor = 0.730
# Iteration 1, Correction=1.565316e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=8.517191e-05, Residual=1.043546e-04, tolerance=1.000000e-08
# Iteration 3, Correction=8.153138e-08, Residual=2.050344e-08, tolerance=1.000000e-08
# Iteration 4, Correction=4.557748e-14, Residual=2.001323e-14, tolerance=1.000000e-08
# Step 73, load factor = 0.740
# Iteration 1, Correction=1.537382e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=7.800719e-05, Residual=1.018105e-04, tolerance=1.000000e-08
# Iteration 3, Correction=6.791385e-08, Residual=1.787724e-08, tolerance=1.000000e-08
# Iteration 4, Correction=3.204999e-14, Residual=1.460683e-14, tolerance=1.000000e-08
# Step 74, load factor = 0.750
# Iteration 1, Correction=1.510855e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=7.167866e-05, Residual=9.958264e-05, tolerance=1.000000e-08
# Iteration 3, Correction=5.704283e-08, Residual=1.564951e-08, tolerance=1.000000e-08
# Iteration 4, Correction=2.297366e-14, Residual=1.101647e-14, tolerance=1.000000e-08
# Step 75, load factor = 0.760
# Iteration 1, Correction=1.485603e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=6.606878e-05, Residual=9.763431e-05, tolerance=1.000000e-08
# Iteration 3, Correction=4.827790e-08, Residual=1.374649e-08, tolerance=1.000000e-08
# Iteration 4, Correction=1.672770e-14, Residual=8.002412e-15, tolerance=1.000000e-08
# Step 76, load factor = 0.770
# Iteration 1, Correction=1.461515e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=6.108444e-05, Residual=9.593526e-05, tolerance=1.000000e-08
# Iteration 3, Correction=4.114692e-08, Residual=1.211256e-08, tolerance=1.000000e-08
# Iteration 4, Correction=1.246318e-14, Residual=6.378413e-15, tolerance=1.000000e-08
# Step 77, load factor = 0.780
# Iteration 1, Correction=1.438495e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=5.665168e-05, Residual=9.446052e-05, tolerance=1.000000e-08
# Iteration 3, Correction=3.529746e-08, Residual=1.070598e-08, tolerance=1.000000e-08
# Iteration 4, Correction=9.422787e-15, Residual=5.469562e-15, tolerance=1.000000e-08
# Step 78, load factor = 0.790
# Iteration 1, Correction=1.416461e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=5.271175e-05, Residual=9.318941e-05, tolerance=1.000000e-08
# Iteration 3, Correction=3.046352e-08, Residual=9.495929e-09, tolerance=1.000000e-08
# Iteration 4, Correction=7.508381e-15, Residual=4.476919e-15, tolerance=1.000000e-08
# Step 79, load factor = 0.800
# Iteration 1, Correction=1.395341e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.921806e-05, Residual=9.210482e-05, tolerance=1.000000e-08
# Iteration 3, Correction=2.644250e-08, Residual=8.460391e-09, tolerance=1.000000e-08
# Iteration 4, Correction=5.617659e-15, Residual=3.970024e-15, tolerance=1.000000e-08
# Step 80, load factor = 0.810
# Iteration 1, Correction=1.375075e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.613378e-05, Residual=9.119269e-05, tolerance=1.000000e-08
# Iteration 3, Correction=2.307915e-08, Residual=7.584751e-09, tolerance=1.000000e-08
# Iteration 4, Correction=5.090549e-15, Residual=3.650602e-15, tolerance=1.000000e-08
# Step 81, load factor = 0.820
# Iteration 1, Correction=1.355611e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.343008e-05, Residual=9.044153e-05, tolerance=1.000000e-08
# Iteration 3, Correction=2.025441e-08, Residual=6.860638e-09, tolerance=1.000000e-08
# Iteration 4, Correction=3.502667e-15, Residual=3.371507e-15, tolerance=1.000000e-08
# Step 82, load factor = 0.830
# Iteration 1, Correction=1.336904e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.108469e-05, Residual=8.984218e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.787776e-08, Residual=6.284780e-09, tolerance=1.000000e-08
# Iteration 4, Correction=2.760660e-15, Residual=3.767421e-15, tolerance=1.000000e-08
# Step 83, load factor = 0.840
# Iteration 1, Correction=1.318917e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.908093e-05, Residual=8.938762e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.588230e-08, Residual=5.857527e-09, tolerance=1.000000e-08
# Iteration 4, Correction=4.261956e-15, Residual=3.198021e-15, tolerance=1.000000e-08
# Step 84, load factor = 0.850
# Iteration 1, Correction=1.301618e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.740712e-05, Residual=8.907280e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.422160e-08, Residual=5.580780e-09, tolerance=1.000000e-08
# Iteration 4, Correction=1.978434e-15, Residual=3.430543e-15, tolerance=1.000000e-08
# Step 85, load factor = 0.860
# Iteration 1, Correction=1.284981e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.605642e-05, Residual=8.889467e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.286811e-08, Residual=5.455626e-09, tolerance=1.000000e-08
# Iteration 4, Correction=1.774523e-15, Residual=3.571749e-15, tolerance=1.000000e-08
# Step 86, load factor = 0.870
# Iteration 1, Correction=1.268987e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.502697e-05, Residual=8.885222e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.181215e-08, Residual=5.480529e-09, tolerance=1.000000e-08
# Iteration 4, Correction=1.376916e-15, Residual=3.617089e-15, tolerance=1.000000e-08
# Step 87, load factor = 0.880
# Iteration 1, Correction=1.253621e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.432268e-05, Residual=8.894661e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.106040e-08, Residual=5.651215e-09, tolerance=1.000000e-08
# Iteration 4, Correction=2.203449e-15, Residual=4.119333e-15, tolerance=1.000000e-08
# Step 88, load factor = 0.890
# Iteration 1, Correction=1.238874e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.395431e-05, Residual=8.918145e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.063266e-08, Residual=5.962657e-09, tolerance=1.000000e-08
# Iteration 4, Correction=1.524315e-15, Residual=3.567164e-15, tolerance=1.000000e-08
# Step 89, load factor = 0.900
# Iteration 1, Correction=1.224742e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.394120e-05, Residual=8.956316e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.055598e-08, Residual=6.412515e-09, tolerance=1.000000e-08
# Iteration 4, Correction=1.601662e-15, Residual=3.767878e-15, tolerance=1.000000e-08
# Step 90, load factor = 0.910
# Iteration 1, Correction=1.211230e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.431341e-05, Residual=9.010151e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.085784e-08, Residual=7.005096e-09, tolerance=1.000000e-08
# Iteration 4, Correction=1.966953e-15, Residual=4.275369e-15, tolerance=1.000000e-08
# Step 91, load factor = 0.920
# Iteration 1, Correction=1.198347e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.511447e-05, Residual=9.081042e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.156323e-08, Residual=7.755639e-09, tolerance=1.000000e-08
# Iteration 4, Correction=3.443701e-15, Residual=3.551949e-15, tolerance=1.000000e-08
# Step 92, load factor = 0.930
# Iteration 1, Correction=1.186111e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.640480e-05, Residual=9.170900e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.269989e-08, Residual=8.695719e-09, tolerance=1.000000e-08
# Iteration 4, Correction=2.987098e-15, Residual=3.993085e-15, tolerance=1.000000e-08
# Step 93, load factor = 0.940
# Iteration 1, Correction=1.174550e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=3.826619e-05, Residual=9.282302e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.431238e-08, Residual=9.881540e-09, tolerance=1.000000e-08
# Iteration 4, Correction=4.557909e-15, Residual=4.290376e-15, tolerance=1.000000e-08
# Step 94, load factor = 0.950
# Iteration 1, Correction=1.163703e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.080791e-05, Residual=9.418712e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.648343e-08, Residual=1.140790e-08, tolerance=1.000000e-08
# Iteration 4, Correction=1.488427e-15, Residual=4.146060e-15, tolerance=1.000000e-08
# Step 95, load factor = 0.960
# Iteration 1, Correction=1.153627e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.417569e-05, Residual=9.584784e-05, tolerance=1.000000e-08
# Iteration 3, Correction=1.936426e-08, Residual=1.343234e-08, tolerance=1.000000e-08
# Iteration 4, Correction=2.965312e-15, Residual=3.916390e-15, tolerance=1.000000e-08
# Step 96, load factor = 0.970
# Iteration 1, Correction=1.144395e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=4.856553e-05, Residual=9.786831e-05, tolerance=1.000000e-08
# Iteration 3, Correction=2.322277e-08, Residual=1.621721e-08, tolerance=1.000000e-08
# Iteration 4, Correction=4.634847e-15, Residual=4.669399e-15, tolerance=1.000000e-08
# Step 97, load factor = 0.980
# Iteration 1, Correction=1.136109e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=5.424565e-05, Residual=1.003353e-04, tolerance=1.000000e-08
# Iteration 3, Correction=2.852995e-08, Residual=2.020367e-08, tolerance=1.000000e-08
# Iteration 4, Correction=3.574475e-15, Residual=6.731616e-15, tolerance=1.000000e-08
# Step 98, load factor = 0.990
# Iteration 1, Correction=1.128910e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=6.159254e-05, Residual=1.033705e-04, tolerance=1.000000e-08
# Iteration 3, Correction=3.612519e-08, Residual=2.614595e-08, tolerance=1.000000e-08
# Iteration 4, Correction=5.341607e-15, Residual=1.021826e-14, tolerance=1.000000e-08
# Step 99, load factor = 1.000
# Iteration 1, Correction=1.122991e-02, Residual=7.856742e-05, tolerance=1.000000e-08
# Iteration 2, Correction=7.115137e-05, Residual=1.071488e-04, tolerance=1.000000e-08
# Iteration 3, Correction=4.754715e-08, Residual=3.536762e-08, tolerance=1.000000e-08
# Iteration 4, Correction=1.239647e-14, Residual=2.100156e-14, tolerance=1.000000e-08

# %% [markdown]
# ## Plot Results
#
# Using matplotlib and the visualization module, we can create plots and animations showing the beam's behavior.

# %%
# Plot the computed u_y vs. x.
plt.figure(figsize=(8, 6))
plt.plot(x_vals, computed_u_y, 'ro-', label="u_x")
plt.xlabel("y (m)")
plt.ylabel("u_y (m)")
plt.title("Final u_y(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()

# Save the plot image to the tutorials directory.
img_fname = tutorials_dir + "/c-final_u_y.png"
plt.savefig(str(img_fname))

# Save an animation of the deformation
img_name = tutorials_dir + "/c-kinking_beam.gif"
gif_displacements = displacements_all
for i_extend in range(20): gif_displacements += [final_disp]
viz.make_deformation_gif(gif_displacements, coords, connect, ele_type, img_name, interval=40)

# %% [markdown]
# ![Buckling beam animation](c-kinking_beam.gif "FEA failure")
#
# This unexpected buckling failure due to extreme compression seems to be very mesh dependent.
# Geometric and numerical instabilities can feed off one another to give such dramatic and nonphysical results, especially when the mesh is too coarse.
#
# ![Final beam shape](c-final_u_y.png "Final beam shape")
